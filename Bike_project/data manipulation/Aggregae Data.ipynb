# %%
import pandas as pd

df = pd.read_excel("C:/Users/DJimenez/Desktop/visual/Bike_project/data/export_data_Jan_Jun_2021.xlsx",  skiprows=3)

def aggregate(df,name):
    df['Flow Name'] = pd.to_datetime(df['Flow Name'], format = '%Y.%m.%d %H:%M')
    #df['Flow Name'] = pd.to_datetime(df['Flow Name']).dt.date
    df['date'] = pd.to_datetime(df['Flow Name']).dt.to_period('M')
    df = df.groupby(["date"]).sum()
    df = df.T
    #Look in the data manipulation folder for out csv file
    df.to_csv("{}.csv".format(name))
    
aggregate(df,"jan_jun_2021_data")

# %%
import pandas as pd
df1 = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/2017_data.csv")
df2= pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/2018_data.csv")
df3 = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/2019_data.csv")
df4 = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/2020_data.csv")

# %%
df1.head()
# Out:
#       date  Rail Runner PdN Trail PED Westbound  \
# 0  2017-01                                  303
# 1  2017-02                                  350
# 2  2017-03                                  640
# 3  2017-04                                42730
# 4  2017-05                                  619
#
#    Rail Runner PdN Trail PED Eastbound  \
# 0                                  334
# 1                                  365
# 2                                  503
# 3                                31621
# 4                                  486
#
#    Rail Runner PdN Trail Bicycle Westbound  \
# 0                                     1363
# 1                                     1673
# 2                                     2523
# 3                                     2488
# 4                                     3157
#
#    Rail Runner PdN Trail Bicycle Eastbound  Erna Fergusson PED Eastbound  \
# 0                                     1319                          2550
# ...

# %%
df = pd.concat([df1,df2,df3,df4], axis=0)
df.set_index("date", inplace=True)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.to_csv("data_bike.csv")
