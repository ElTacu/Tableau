# %%
import pandas as pd

#df = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/Bike_names_edited.csv")
df = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/data manipulation/jan_jun_2021_data.csv")
df = df.melt(id_vars="Location", var_name="Date", value_name="Value")
tem = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/temple.csv")


dates = set(df.Date.tolist())

new = [item for item in dates for i in range(7)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-03d472990404> in <module>()
#       3 #df = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/Bike_names_edited.csv")
#       4 df = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/data manipulation/jan_jun_2021_data.csv")
# ----> 5 df = df.melt(id_vars="Location", var_name="Date", value_name="Value")
#       6 tem = pd.read_csv("C:/Users/DJimenez/Desktop/visual/Bike_project/temple.csv")
#       7
#
# C:\Anaconda2\lib\site-packages\pandas\core\frame.pyc in melt(self, id_vars, value_vars, var_name, value_name, col_level)
#    5636         return melt(self, id_vars=id_vars, value_vars=value_vars,
#    5637                     var_name=var_name, value_name=value_name,
# -> 5638                     col_level=col_level)
#    5639
# ...

# %%
all_temp = pd.concat([tem]*48)
all_temp = all_temp.assign(date=new)
all_temp = all_temp.sort_values(by=['date'])

# %%
for index, row in df.iterrows():
    year = row[1]
    loc = row[0].lower()
    if "jerry cline park" in loc:
        
        if "pedestrians" in loc or "ped" in loc:
            if "west" in loc or "south" in loc:
                all_temp['ped_west_sout'][(all_temp.date == year) & (all_temp.location == "jerry cline park")] = row[2]
            else:
                all_temp['ped_east_north'][(all_temp.date == year) & (all_temp.location == "jerry cline park")] = row[2]
        
        else:
            if "west" in loc or "south" in loc:
                all_temp['bike_west_sout'][(all_temp.date == year) & (all_temp.location == "jerry cline park")] = row[2]
            else:
                all_temp['bike_east_north'][(all_temp.date == year) & (all_temp.location == "jerry cline park")] = row[2]
                
                
    if "erna fergusson library" in loc:
        
        if "pedestrians" in loc or "ped" in loc:
            if "west" in loc or "south" in loc:
                all_temp['ped_west_sout'][(all_temp.date == year) & (all_temp.location == "erna fergusson library")] = row[2]
            else:
                all_temp['ped_east_north'][(all_temp.date == year) & (all_temp.location == "erna fergusson library")] = row[2]
        
        else:
            if "west" in loc or "south" in loc:
                all_temp['bike_west_sout'][(all_temp.date == year) & (all_temp.location == "erna fergusson library")] = row[2]
            else:
                all_temp['bike_east_north'][(all_temp.date == year) & (all_temp.location == "erna fergusson library")] = row[2]
                
                
    if "north diversion channel trail & indian school rd" in loc:

        if "pedestrians" in loc or "ped" in loc:
            if "west" in loc or "south" in loc:
                all_temp['ped_west_sout'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & indian school rd")] = row[2]
            else:
                all_temp['ped_east_north'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & indian school rd")] = row[2]
        
        else:
            if "west" in loc or "south" in loc:
                all_temp['bike_west_sout'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & indian school rd")] = row[2]
            else:
                all_temp['bike_east_north'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & indian school rd")] = row[2]
    
    
    
    if "north diversion channel trail & journal center" in loc:
        
        if "pedestrians" in loc or "ped" in loc:
            if "west" in loc or "south" in loc:
                all_temp['ped_west_sout'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & journal center")] = row[2]
            else:
                all_temp['ped_east_north'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & journal center")] = row[2]
        
        else:
            if "west" in loc or "south" in loc:
                all_temp['bike_west_sout'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & journal center")] = row[2]
            else:
                all_temp['bike_east_north'][(all_temp.date == year) & (all_temp.location == "north diversion channel trail & journal center")] = row[2]
                
                
                
    if "paseo del bosque & montano rd" in loc:
        
        if "pedestrians" in loc or "ped" in loc:
            if "west" in loc or "south" in loc:
                all_temp['ped_west_sout'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & montano rd")] = row[2]
            else:
                all_temp['ped_east_north'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & montano rd")] = row[2]
        
        else:
            if "west" in loc or "south" in loc:
                all_temp['bike_west_sout'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & montano rd")] = row[2]
            else:
                all_temp['bike_east_north'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & montano rd")] = row[2]
                
    
    if "paseo del bosque & tingley beach" in loc:
        
        if "pedestrians" in loc or "ped" in loc:
            if "west" in loc or "south" in loc:
                all_temp['ped_west_sout'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & tingley beach")] = row[2]
            else:
                all_temp['ped_east_north'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & tingley beach")] = row[2]
        
        else:
            if "west" in loc or "south" in loc:
                all_temp['bike_west_sout'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & tingley beach")] = row[2]
            else:
                all_temp['bike_east_north'][(all_temp.date == year) & (all_temp.location == "paseo del bosque & tingley beach")] = row[2]         
        
        
    if "paseo del norte & rail runner" in loc:
        
        if "pedestrians" in loc or "ped" in loc:
            if "west" in loc or "south" in loc:
                all_temp['ped_west_sout'][(all_temp.date == year) & (all_temp.location == "paseo del norte & rail runner")] = row[2]
            else:
                all_temp['ped_east_north'][(all_temp.date == year) & (all_temp.location == "paseo del norte & rail runner")] = row[2]
        
        else:
            if "west" in loc or "south" in loc:
                all_temp['bike_west_sout'][(all_temp.date == year) & (all_temp.location == "paseo del norte & rail runner")] = row[2]
            else:
                all_temp['bike_east_north'][(all_temp.date == year) & (all_temp.location == "paseo del norte & rail runner")] = row[2]
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Anaconda2\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# ...

# %%
all_temp.to_csv("bike_final.csv", index = False)
